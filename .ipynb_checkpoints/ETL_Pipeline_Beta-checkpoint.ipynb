# %% [markdown]
# <h1 style="color:red;">ETL Pipeline</h1>
# <hr/>
# <p>Small Demo using ETL Pipeline</p>
# <h3>Loading Required Library</h3>

# %%
import os
import pandas as pd
from openpyxl import load_workbook
from pyxlsb import open_workbook

# %% [markdown]
# <h3>Reading Files</h3>

# %%
records = []
file_count = 0

ROOT_FOLDER = r"C:\Barry\RootFolder"

system_names = [
    name for name in os.listdir(ROOT_FOLDER)
    if os.path.isdir(os.path.join(ROOT_FOLDER, name))
]

# %%
system_names
# Out:
# ['System_A', 'System_B']

# %%
for root, dirs, files in os.walk(ROOT_FOLDER):
    for file in files:
        file_count+=1
        if file.lower().endswith(('.csv', '.xlsx', '.xlsb', '.xls')):
            print(file)
# Out:
# 2021_Jun_ALPHA_dump.xlsx
# 2021_Oct_ALPHA_dump.xlsx
# ALPHA FY21 April Extract FINAL.xlsx
# ALPHA FY21 August Extract FINAL.xlsx
# ALPHA FY21 December Extract FINAL.xlsx
# ALPHA-2021-03 raw.xlsx
# ALPHA-2021-09 raw.xlsx
# ALPHA__Feb-2021__export (draft).xlsx
# ALPHA__Jan-2021__export (draft).xlsx
# July_2021__ALPHA__HIST.xlsx
# May_2021__ALPHA__HIST.xlsx
# November_2021__ALPHA__HIST.xlsx
# 2022_Dec_ALPHA_dump.xlsx
# 2022_Jul_ALPHA_dump.xlsx
# ALPHA FY22 February Extract FINAL.xlsx
# ALPHA FY22 May Extract FINAL.xlsx
# ALPHA FY22 October Extract FINAL.xlsx
# ALPHA-2022-11 raw.xlsx
# ALPHA_Extract__04_2022__v2.xlsx
# ALPHA__2022.01__REPORT.xlsx
# ALPHA__2022.03__REPORT.xlsx
# ALPHA__2022.08__REPORT.xlsx
# June_2022__ALPHA__HIST.xlsx
# September_2022__ALPHA__HIST.xlsx
# ALPHA FY23 July Extract FINAL.xlsx
# ALPHA FY23 October Extract FINAL.xlsx
# ALPHA FY23 September Extract FINAL.xlsx
# ALPHA_Extract__03_2023__v2.xlsx
# ALPHA_Extract__11_2023__v3.xlsx
# ALPHA__Apr-2023__export (draft).xlsx
# ALPHA__Aug-2023__export (draft).xlsx
# ALPHA__Dec-2023__export (draft).xlsx
# ALPHA__Feb-2023__export (draft).xlsx
# January_2023__ALPHA__HIST.xlsx
# June_2023__ALPHA__HIST.xlsx
# May_2023__ALPHA__HIST.xlsx
# ALPHA FY24 December Extract FINAL.xlsx
# ALPHA FY24 July Extract FINAL.xlsx
# ALPHA-2024-01 raw.xlsx
# ALPHA-2024-09 raw.xlsx
# ALPHA_Extract__05_2024__v1.xlsx
# ALPHA_Extract__08_2024__v1.xlsx
# ALPHA__2024.10__REPORT.xlsx
# ALPHA__2024.11__REPORT.xlsx
# ALPHA__Apr-2024__export (draft).xlsx
# February_2024__ALPHA__HIST.xlsx
# June_2024__ALPHA__HIST.xlsx
# March_2024__ALPHA__HIST.xlsx
# 2021_Dec_BETA_dump.xlsx
# 2021_Oct_BETA_dump.xlsx
# BETA FY21 February Extract FINAL.xlsx
# BETA FY21 May Extract FINAL.xlsx
# BETA FY21 September Extract FINAL.xlsx
# BETA-2021-01 raw.xlsx
# BETA_Extract__04_2021__v1.xlsx
# BETA_Extract__07_2021__v2.xlsx
# BETA__2021.03__REPORT.xlsx
# BETA__2021.08__REPORT.xlsx
# June_2021__BETA__HIST.xlsx
# November_2021__BETA__HIST.xlsx
# 2022_Mar_BETA_dump.xlsx
# 2022_Oct_BETA_dump.xlsx
# 2022_Sep_BETA_dump.xlsx
# BETA FY22 August Extract FINAL.xlsx
# BETA-2022-02 raw.xlsx
# BETA_Extract__04_2022__v3.xlsx
# BETA__2022.01__REPORT.xlsx
# BETA__2022.07__REPORT.xlsx
# BETA__2022.11__REPORT.xlsx
# BETA__2022.12__REPORT.xlsx
# BETA__May-2022__export (draft).xlsx
# June_2022__BETA__HIST.xlsx
# 2023_Feb_BETA_dump.xlsx
# 2023_Jan_BETA_dump.xlsx
# BETA FY23 May Extract FINAL.xlsx
# BETA_Extract__03_2023__v2.xlsx
# BETA_Extract__04_2023__v2.xlsx
# BETA_Extract__08_2023__v1.xlsx
# BETA__2023.06__REPORT.xlsx
# BETA__2023.07__REPORT.xlsx
# BETA__Nov-2023__export (draft).xlsx
# BETA__Oct-2023__export (draft).xlsx
# BETA__Sep-2023__export (draft).xlsx
# December_2023__BETA__HIST.xlsx
# 2024_Feb_BETA_dump.xlsx
# 2024_Jul_BETA_dump.xlsx
# April_2024__BETA__HIST.xlsx
# BETA FY24 August Extract FINAL.xlsx
# BETA FY24 March Extract FINAL.xlsx
# BETA FY24 October Extract FINAL.xlsx
# BETA-2024-05 raw.xlsx
# BETA-2024-06 raw.xlsx
# BETA_Extract__01_2024__v2.xlsx
# BETA_Extract__11_2024__v2.xlsx
# BETA__Sep-2024__export (draft).xlsx
# December_2024__BETA__HIST.xlsx
